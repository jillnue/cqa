# %%
import pandas as pd

# %%
data = pd.read_csv('./fama.txt', header = None, sep = " ", error_bad_lines=False)
# Out:
# b'Skipping line 6: expected 7 fields, saw 8\nSkipping line 7: expected 7 fields, saw 8\nSkipping line 8: expected 7 fields, saw 8\nSkipping line 9: expected 7 fields, saw 8\nSkipping line 10: expected 7 fields, saw 8\nSkipping line 11: expected 7 fields, saw 8\nSkipping line 21: expected 7 fields, saw 8\nSkipping line 31: expected 7 fields, saw 8\nSkipping line 32: expected 7 fields, saw 8\nSkipping line 34: expected 7 fields, saw 8\nSkipping line 47: expected 7 fields, saw 8\nSkipping line 62: expected 7 fields, saw 8\nSkipping line 68: expected 7 fields, saw 8\nSkipping line 69: expected 7 fields, saw 8\nSkipping line 70: expected 7 fields, saw 8\nSkipping line 89: expected 7 fields, saw 8\nSkipping line 91: expected 7 fields, saw 8\nSkipping line 100: expected 7 fields, saw 8\nSkipping line 101: expected 7 fields, saw 8\nSkipping line 146: expected 7 fields, saw 8\nSkipping line 149: expected 7 fields, saw 8\nSkipping line 161: expected 7 fields, saw 8\nSkipping line 164: expected
# ...

# %%
data
# Out:
#               0               1         2         3         4         5  \
# 0    2016-11-08  14:31:00+00:00       NaN  0.990474 -1.941435       NaN
# 1    2016-11-09  14:31:00+00:00       NaN  2.083929 -1.722483       NaN
# 2    2016-11-10  14:31:00+00:00       NaN  3.615208 -0.323271 -0.293212
# 3    2016-11-11  14:31:00+00:00       NaN  4.004412       NaN  0.592384
# 4    2016-11-14  14:31:00+00:00       NaN  1.581417       NaN  2.798087
# 5    2016-11-23  14:31:00+00:00       NaN  1.188400 -0.051578       NaN
# 6    2016-11-25  14:31:00+00:00       NaN  0.812971       NaN  0.173479
# 7    2016-11-28  14:31:00+00:00       NaN  1.382088 -0.005996 -0.753483
# 8    2016-11-29  14:31:00+00:00       NaN  0.190814       NaN  0.451570
# 9    2016-11-30  14:31:00+00:00       NaN  0.163243       NaN  0.083141
# 10   2016-12-01  14:31:00+00:00 -0.181217 -0.420576       NaN  1.258896
# 11   2016-12-02  14:31:00+00:00 -0.902812 -0.475199       NaN  2.314211
# ...
