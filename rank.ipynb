# %%
import pandas as pd

# %%
alpha = pd.read_csv('./alpha.csv', sep =',')

# %%
alpha
# Out:
#       ,"Alpha_Three_Factor","Sector"
# 0        A,0.00250844845386384,"xlv"
# 1       AA,0.00300957816794688,"xli"
# 2      AAL,0.00156036524819154,"xli"
# 3     AAP,-0.00145293280975526,"xly"
# 4     AAPL,0.00229740162713914,"xlk"
# 5     ABBV,0.00237948428792636,"xlv"
# 6      ABC,0.00110424924755214,"xlv"
# 7     ABMD,0.00300809247914485,"xlv"
# 8      ABT,0.00170965123722859,"xlv"
# 9     ACAD,0.00133626789907111,"xlv"
# 10   ACC,-0.000215384261590717,"xly"
# 11   ACGL,0.000834231795673294,"xlf"
# 12    ACHC,0.00128203911673531,"xlv"
# 13     ACM,0.00128187403976189,"xly"
# 14     ACN,0.00126079965440282,"xlk"
# 15    ADBE,0.00286006399125262,"xlk"
# 16     ADI,0.00136914144793337,"xlk"
# 17   ADM,-0.000249374308222051,"xlp"
# 18    ADNT,0.00221101012889657,"xlp"
# 19    ADP,0.000621948939575959,"xlk"
# 20     ADS,0.00118015723102798,"xlk"
# 21    ADSK,0.00359064371624859,"xlk"
# 22    AEE,0.000996638668565523,"xlu"
# 23     AEP,0.00102472727846229,"xlu"
# ...

# %%
beta = pd.read_excel('./basic_data/universe_beta.xlsx', index_col=0)

# %%
alpha['beta']=beta.Beta

# %%
alpha.head()
# Out:
#                                beta
# ,"Alpha_Three_Factor","Sector"
# A,0.00250844845386384,"xlv"     NaN
# AA,0.00300957816794688,"xli"    NaN
# AAL,0.00156036524819154,"xli"   NaN
# AAP,-0.00145293280975526,"xly"  NaN
# AAPL,0.00229740162713914,"xlk"  NaN

# %%
sector = ['xly','xlp','xle','xlf','xlv','xli','xlb','xlre','xlk','xlu']
for sym in sector:
    alpha[alpha.Sector==sym].sort(columns = 'Alpha_Three_Factor',ascending=True).to_csv('./rank_result/'+sym+'_rank.csv')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pd.read_csv('./rank')
# Out:
#        Alpha_Three_Factor Sector    beta
# AIV              0.000521   xlre  0.6935
# AMT              0.001654   xlre   0.839
# ARE              0.001188   xlre  0.7228
# AVB              0.000664   xlre  0.6209
# BXP              0.000425   xlre  0.8407
# CBG              0.001848   xlre  1.5079
# CCI              0.001967   xlre   0.632
# DLR              0.002043   xlre    0.66
# DRE              0.001670   xlre  0.8408
# EQIX             0.002220   xlre  0.9287
# EQR              0.000856   xlre  0.6263
# ESS              0.000651   xlre  0.6467
# EXR              0.000828   xlre  0.5644
# FCE-A            0.001871   xlre     NaN
# FRT              0.000099   xlre  0.6726
# GGP             -0.000015   xlre  0.8196
# HCN              0.001065   xlre  0.5909
# HCP              0.000380   xlre  0.6871
# HST              0.001815   xlre  1.1901
# IRM              0.002012   xlre  0.8704
# KIM             -0.000579   xlre  0.7593
# MAA              0.000681   xlre  0.5847
# ...
